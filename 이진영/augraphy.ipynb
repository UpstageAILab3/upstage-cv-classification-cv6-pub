# %%
# !pip install augraphy
# Out:
# Requirement already satisfied: augraphy in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (8.2.6)
# Requirement already satisfied: matplotlib>=3.4.3 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from augraphy) (3.8.4)
# Requirement already satisfied: numba>=0.57.0 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from augraphy) (0.60.0)
# Requirement already satisfied: numpy>=1.20.1 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from augraphy) (1.23.5)
# Requirement already satisfied: opencv-python>=4.5.1.48 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from augraphy) (4.8.1.78)
# Requirement already satisfied: Pillow>=8.0.0 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from augraphy) (9.4.0)
# Requirement already satisfied: requests>=2.25.1 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from augraphy) (2.32.3)
# Requirement already satisfied: scikit-image>=0.18.1 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from augraphy) (0.23.2)
# Requirement already satisfied: scikit-learn>=0.23.2 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from augraphy) (1.4.2)
# Requirement already satisfied: scipy>=1.6.3 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from augraphy) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from matplotlib>=3.4.3->augraphy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from matplotlib>=3.4.3->augraphy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from matplotlib>=3.4.3->augraphy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from matplotlib>=3.4.3->augraphy) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from matplotlib>=3.4.3->augraphy) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from matplotlib>=3.4.3->augraphy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from matplotlib>=3.4.3->augraphy) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from numba>=0.57.0->augraphy) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from requests>=2.25.1->augraphy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from requests>=2.25.1->augraphy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from requests>=2.25.1->augraphy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from requests>=2.25.1->augraphy) (2024.7.4)
# Requirement already satisfied: networkx>=2.8 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from scikit-image>=0.18.1->augraphy) (3.3)
# Requirement already satisfied: imageio>=2.33 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from scikit-image>=0.18.1->augraphy) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from scikit-image>=0.18.1->augraphy) (2023.4.12)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from scikit-image>=0.18.1->augraphy) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from scikit-learn>=0.23.2->augraphy) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from scikit-learn>=0.23.2->augraphy) (3.5.0)
# Requirement already satisfied: six>=1.5 in /Users/jlee/anaconda3/envs/noname/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.4.3->augraphy) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from augraphy import *

# %%
pipeline = default_augraphy_pipeline()
image = cv.imread("image.png")
image_augmented = pipeline(image)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)
plt.imshow(image)

plt.subplot(1, 2, 2)
plt.imshow(image_augmented)
