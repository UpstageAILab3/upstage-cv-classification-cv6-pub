# %%
# %pwd
# Out:
# 'c:\\Users\\jsy61\\Documents\\dev\\angledetection\\deep-image-orientation-angle-detection\\notebooks'

# %%
import os
os.chdir("../")

# %%
# Import libraries
import numpy as np
import glob
from infer import Inference
# Out:
# c:\Users\jsy61\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\models\vit\feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(

# %%
# load model
model = Inference()
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFViTModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing TFViTModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFViTModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFViTModel were not initialized from the PyTorch model and are newly initialized: ['vit.pooler.dense.weight', 'vit.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "model"
# _________________________________________________________________
# ...

# %%
from loguru import logger
# Get the list of image paths
image_paths = glob.glob("inputs/*")

# Prepare an array to store predictions
y_pred = np.zeros(shape=(len(image_paths), ))

# Loop through each image, make predictions, and save processed images
for i, path in enumerate(image_paths):
    # Make prediction and get the processed image
    y_pred[i], _ = model.predict(model_name="vit", image_path=path, postprocess_and_save=True)
    

# Print the predictions
print(y_pred)
# Out:
# ...
# 1/1 [==============================] - 0s 189ms/step
# ...
# ...
# 1/1 [==============================] - 0s 190ms/step
# [61.64184189 92.734375   93.65612793 ...  0.517874   -2.33030224
#   0.17835265]

# %%
pred_df['target'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pred_df['target'].value_counts()
#
# NameError: name 'pred_df' is not defined
